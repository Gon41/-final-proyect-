# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame
import requests
from dotenv import load_dotenv
import os
import re
import json
from pandas.io.json import json_normalize
import folium

# %%
# Importar el acceso al archivo

load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. Spanish Restaurant

# %%
def data_api(ll,query,limit,name_database):
    
    url = 'https://api.foursquare.com/v2/venues/explore'    # Dirección de la API
   
    params = dict(
    client_id=os.getenv("FQ_CLIENT_ID"),                    # Verificación ID de acceso          
    client_secret=os.getenv("FQ_CLIENT_SECRET"),            # Verificación claves de acceso
    v='20201201',                                           # Fecha de actualización
    ll=ll,
    radius="10000",                                           # Coordenadas principales para buscar a partir de ellas
    query=query,                                            # ¿Qué estamos buscando?
    limit=limit)
    resp = requests.get(url=url, params=params)             # Buscar en la url definida con los parámetros elegidos
    name_database = json.loads(resp.text)                   # Convertirlo en un json y convertir la búsqueda en texto

    return name_database

# %%
spanish_restaurant = data_api("40.4146500,-3.7004000","Spanish Restaurant",500,"spanish_restaurant")

print(spanish_restaurant["response"]["totalResults"])

spanish_restaurant
# Out:
# 222
# {'meta': {'code': 200, 'requestId': '5fd73dcf6afa204b7254e019'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Madrid',
#   'headerFullLocation': 'Madrid',
#   'headerLocationGranularity': 'city',
#   'query': 'spanish restaurant',
#   'totalResults': 222,
#   'suggestedBounds': {'ne': {'lat': 40.50465009000009,
#     'lng': -3.582413019991607},
#    'sw': {'lat': 40.32464990999991, 'lng': -3.8183869800083934}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5877d4aed4ab730fcf09092b',
#        'name': 'Toga',
#        'location': {'address': 'Calle Juanelo 23',
#         'lat': 40.41111841899132,
#         'lng': -3.70667299456038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41111841899132,
#           'lng': -3.70667299456038}],
#         'distance': 661,
#         'postalCode': '28008',
#         'cc': 'ES',
#         'neighborhood': 'Lavapiés',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Juanelo 23',
#          '28008 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5877d4aed4ab730fcf09092b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5054f76be4b0c2107499b3a7',
#        'name': 'El Barril de las Letras',
#        'location': {'address': 'C. Cervantes, 28',
#         'lat': 40.41435989216732,
#         'lng': -3.6967134353360627,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41435989216732,
#           'lng': -3.6967134353360627}],
#         'distance': 314,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'neighborhood': 'Huertas',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Cervantes, 28',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5054f76be4b0c2107499b3a7-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbbaf8ded7776b0cac63e51',
#        'name': 'Casa Pueblo',
#        'location': {'address': 'Leon 3',
#         'lat': 40.41461381230456,
#         'lng': -3.6985981117031463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41461381230456,
#           'lng': -3.6985981117031463}],
#         'distance': 152,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Leon 3', '28014 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbbaf8ded7776b0cac63e51-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5962873e58aa7f4a588a54a0',
#        'name': 'Astór Gastrobar',
#        'location': {'address': '9 Calle del Almendro',
#         'lat': 40.41273,
#         'lng': -3.709617,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41273,
#           'lng': -3.709617}],
#         'distance': 809,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['9 Calle del Almendro',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5962873e58aa7f4a588a54a0-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb2605414cfd13aa2da14ab',
#        'name': 'El Paraguas',
#        'location': {'address': 'C. Jorge Juan, 16',
#         'lat': 40.42386542247894,
#         'lng': -3.685813532393988,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42386542247894,
#           'lng': -3.685813532393988}],
#         'distance': 1606,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Jorge Juan, 16',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb2605414cfd13aa2da14ab-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57274306498ecb4252a70a34',
#        'name': 'Cannibal Raw Bar',
#        'location': {'address': 'Calle Almirante 12',
#         'crossStreet': 'Calle Conde de Xiquena',
#         'lat': 40.42250153573088,
#         'lng': -3.694248172533777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42250153573088,
#           'lng': -3.694248172533777}],
#         'distance': 1017,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Almirante 12 (Calle Conde de Xiquena)',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57274306498ecb4252a70a34-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda34f964a520ed3a21e3',
#        'name': 'Restaurante Viva Madrid',
#        'location': {'address': 'C. Manuel Fernández y González, 7',
#         'lat': 40.41516746717612,
#         'lng': -3.6998336282593405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41516746717612,
#           'lng': -3.6998336282593405}],
#         'distance': 74,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Manuel Fernández y González, 7',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '90443461'}},
#       'referralId': 'e-0-4adcda34f964a520ed3a21e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9fdf51f964a520594637e3',
#        'name': 'Bodegas Rosell',
#        'location': {'address': 'C. General Lacy, 14',
#         'lat': 40.403802520431654,
#         'lng': -3.6906202941279647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.403802520431654,
#           'lng': -3.6906202941279647}],
#         'distance': 1464,
#         'postalCode': '28045',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. General Lacy, 14',
#          '28045 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9fdf51f964a520594637e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9e79aef964a52026e736e3',
#        'name': 'Mercado de Antón Martín',
#        'location': {'address': 'Calle de Santa Isabel 5',
#         'lat': 40.41152590000001,
#         'lng': -3.6987288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41152590000001,
#           'lng': -3.6987288}],
#         'distance': 375,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Santa Isabel 5',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '509208128'}},
#       'referralId': 'e-0-4b9e79aef964a52026e736e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9cdc768afca093b936f115',
#        'name': 'Bar La Campana',
#        'location': {'address': 'C. Botoneras, 4',
#         'lat': 40.414881954231625,
#         'lng': -3.706774570000363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414881954231625,
#           'lng': -3.706774570000363}],
#         'distance': 540,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Botoneras, 4',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9cdc768afca093b936f115-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '552cc0cd498e4bba96669cb2',
#        'name': 'Pez Tortilla',
#        'location': {'address': 'C. Pez, 36',
#         'lat': 40.4242382067626,
#         'lng': -3.706568309829162,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4242382067626,
#           'lng': -3.706568309829162}],
#         'distance': 1188,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Pez, 36', '28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-552cc0cd498e4bba96669cb2-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5264e19f498e56f27ddeb9ea',
#        'name': 'La Maruca',
#        'location': {'address': 'C. Velázquez, 54',
#         'lat': 40.42747655521919,
#         'lng': -3.6839650810190783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42747655521919,
#           'lng': -3.6839650810190783}],
#         'distance': 1994,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Velázquez, 54',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5264e19f498e56f27ddeb9ea-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc5b03f6c26b7132f8febf3',
#        'name': 'La Manduca de Azagra',
#        'location': {'address': 'Calle SAGASTA, 14, BAJO',
#         'lat': 40.428413255,
#         'lng': -3.69965323,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.428413255,
#           'lng': -3.69965323}],
#         'distance': 1533,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle SAGASTA, 14, BAJO',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc5b03f6c26b7132f8febf3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c50384af080a593a66624e2',
#        'name': 'Membibre',
#        'location': {'address': 'Guzman el bueno, 40',
#         'lat': 40.434911771333695,
#         'lng': -3.7131862406723166,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.434911771333695,
#           'lng': -3.7131862406723166}],
#         'distance': 2502,
#         'cc': 'ES',
#         'neighborhood': 'Gaztambide',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Guzman el bueno, 40',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c50384af080a593a66624e2-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3925d8f964a5202a5725e3',
#        'name': 'Las Tortillas de Gabino',
#        'location': {'address': 'C. Rafael Calvo, 20',
#         'lat': 40.43397126970508,
#         'lng': -3.693840964089531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43397126970508,
#           'lng': -3.693840964089531}],
#         'distance': 2221,
#         'postalCode': '28010',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Rafael Calvo, 20',
#          '28010 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '47059860'}},
#       'referralId': 'e-0-4b3925d8f964a5202a5725e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c09679d7e3fc928edeaf182',
#        'name': 'Museo del Jamón',
#        'location': {'address': 'C. Mayor, 7',
#         'lat': 40.416343036500216,
#         'lng': -3.7056822482813363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416343036500216,
#           'lng': -3.7056822482813363}],
#         'distance': 485,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Mayor, 7', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c09679d7e3fc928edeaf182-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c11101581e976b0422010eb',
#        'name': 'Venta El Buscón',
#        'location': {'address': 'C. Victoria, 5',
#         'lat': 40.41611688876583,
#         'lng': -3.7017447829143073,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41611688876583,
#           'lng': -3.7017447829143073}],
#         'distance': 199,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Victoria, 5',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c11101581e976b0422010eb-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7bf438f964a52096752fe3',
#        'name': 'El Senador',
#        'location': {'address': 'Plaza de La Marina Española, 2',
#         'lat': 40.42076966674159,
#         'lng': -3.7114585151950705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42076966674159,
#           'lng': -3.7114585151950705}],
#         'distance': 1158,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza de La Marina Española, 2',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7bf438f964a52096752fe3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54d13184498e14bbb0b7f4a0',
#        'name': 'La Tasquería',
#        'location': {'address': 'Duque de Sesto 48',
#         'lat': 40.42238601054716,
#         'lng': -3.673697687593717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42238601054716,
#           'lng': -3.673697687593717}],
#         'distance': 2421,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid Centro, Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Duque de Sesto 48',
#          '28009 Madrid Centro Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54d13184498e14bbb0b7f4a0-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb51b4ce4b07727d0d2844a',
#        'name': 'Muñagorri',
#        'location': {'address': 'C. Padilla, 56',
#         'lat': 40.43129825360115,
#         'lng': -3.6773280703427838,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43129825360115,
#           'lng': -3.6773280703427838}],
#         'distance': 2693,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Padilla, 56',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '53887741'}},
#       'referralId': 'e-0-4fb51b4ce4b07727d0d2844a-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee738d5e5e8ed8c64f2eb10',
#        'name': 'Restaurante Lakasa',
#        'location': {'address': 'Pl. Descubridor Diego de Ordás, 1',
#         'crossStreet': 'Santa Engracia, 120',
#         'lat': 40.440735363841156,
#         'lng': -3.700766735265493,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.440735363841156,
#           'lng': -3.700766735265493}],
#         'distance': 2903,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Descubridor Diego de Ordás, 1 (Santa Engracia, 120)',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34016783'}},
#       'referralId': 'e-0-4ee738d5e5e8ed8c64f2eb10-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf86556b182c9b69272775a',
#        'name': 'Cabreira',
#        'location': {'address': 'C. Ruiz, 2',
#         'lat': 40.42735906133265,
#         'lng': -3.7039847530463748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42735906133265,
#           'lng': -3.7039847530463748}],
#         'distance': 1447,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Ruiz, 2', '28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf86556b182c9b69272775a-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec901e54690116a8de65de1',
#        'name': 'Cañadío',
#        'location': {'address': 'C. Conde de Peñalver, 86',
#         'crossStreet': 'C. Maldonado',
#         'lat': 40.433172445427076,
#         'lng': -3.675035662601485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.433172445427076,
#           'lng': -3.675035662601485}],
#         'distance': 2978,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'neighborhood': 'Lista',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Conde de Peñalver, 86 (C. Maldonado)',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec901e54690116a8de65de1-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5802485738facea404599aa5',
#        'name': 'Castelados',
#        'location': {'address': 'C. Antonio Acuña, 18',
#         'lat': 40.42070698286369,
#         'lng': -3.6790904867593115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42070698286369,
#           'lng': -3.6790904867593115}],
#         'distance': 1927,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Antonio Acuña, 18',
#          '28009 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5802485738facea404599aa5-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b637e6df964a520367e2ae3',
#        'name': 'Lamucca',
#        'location': {'address': 'Pl. de Carlos Cambronero 4',
#         'crossStreet': 'C. Pez',
#         'lat': 40.423160346582144,
#         'lng': -3.7040597217866043,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423160346582144,
#           'lng': -3.7040597217866043}],
#         'distance': 996,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Carlos Cambronero 4 (C. Pez)',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b637e6df964a520367e2ae3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba38fb9f964a5208b4738e3',
#        'name': 'El Pimiento Verde',
#        'location': {'address': 'C. Quintana, 1',
#         'lat': 40.428865543369945,
#         'lng': -3.7154014044180075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.428865543369945,
#           'lng': -3.7154014044180075}],
#         'distance': 2029,
#         'postalCode': '28008',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Quintana, 1',
#          '28008 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba38fb9f964a5208b4738e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb5280cef159c74b05c74f7',
#        'name': 'Cuevas El Secreto',
#        'location': {'address': 'C. Barcelona, 2',
#         'crossStreet': 'C. Cadiz',
#         'lat': 40.41571802886517,
#         'lng': -3.7026156381668383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41571802886517,
#           'lng': -3.7026156381668383}],
#         'distance': 222,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Barcelona, 2 (C. Cadiz)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb5280cef159c74b05c74f7-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59ab71f964a520da9128e3',
#        'name': 'El Gran Barril',
#        'location': {'address': 'C. Goya, 107',
#         'lat': 40.424551794594144,
#         'lng': -3.6731258506053215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.424551794594144,
#           'lng': -3.6731258506053215}],
#         'distance': 2560,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Goya, 107', '28009 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b59ab71f964a520da9128e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52acda1711d227be95df39c5',
#        'name': 'Makkila Serrano',
#        'location': {'address': 'C. Serrano, 110',
#         'crossStreet': 'C. Diego De León',
#         'lat': 40.435157917226896,
#         'lng': -3.686353353436428,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.435157917226896,
#           'lng': -3.686353353436428}],
#         'distance': 2574,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Serrano, 110 (C. Diego De León)',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52acda1711d227be95df39c5-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4dd66cb887a1cd738cc0a0',
#        'name': 'TreZe Restaurante & Bar',
#        'location': {'address': 'C/ general pardiñas 36',
#         'lat': 40.42718847645551,
#         'lng': -3.678429449556118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42718847645551,
#           'lng': -3.678429449556118}],
#         'distance': 2327,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ general pardiñas 36',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '47094201'}},
#       'referralId': 'e-0-4d4dd66cb887a1cd738cc0a0-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54ab0448498ec0e90483b287',
#        'name': 'la gaditana',
#        'location': {'address': 'Calle Fuente Del Berri 23',
#         'lat': 40.42486448041017,
#         'lng': -3.670859723201479,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42486448041017,
#           'lng': -3.670859723201479}],
#         'distance': 2749,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Fuente Del Berri 23',
#          '28009 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54ab0448498ec0e90483b287-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc8ca7492b376b02735523a',
#        'name': 'O Pazo de Lugo',
#        'location': {'address': 'C. Argumosa 28',
#         'lat': 40.407589,
#         'lng': -3.696473,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.407589,
#           'lng': -3.696473}],
#         'distance': 853,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Argumosa 28',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50604958'}},
#       'referralId': 'e-0-4bc8ca7492b376b02735523a-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be5ada39026ef3b9ac30a38',
#        'name': 'La Casa del Abuelo',
#        'location': {'address': 'C. Victoria, 12',
#         'lat': 40.4158078467863,
#         'lng': -3.701593251107847,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4158078467863,
#           'lng': -3.701593251107847}],
#         'distance': 163,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Victoria, 12',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be5ada39026ef3b9ac30a38-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f005f20e5faf2869c3c7b0c',
#        'name': 'La Antoñita',
#        'location': {'address': 'C. Cava Baja, 14',
#         'lat': 40.4130849147541,
#         'lng': -3.7085505691060217,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4130849147541,
#           'lng': -3.7085505691060217}],
#         'distance': 712,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Cava Baja, 14',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f005f20e5faf2869c3c7b0c-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3af964a520403d21e3',
#        'name': 'Casa Benigna',
#        'location': {'address': 'C. Benigno Soto, 9',
#         'lat': 40.44809073514549,
#         'lng': -3.6742265886202774,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44809073514549,
#           'lng': -3.6742265886202774}],
#         'distance': 4333,
#         'postalCode': '28002',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Benigno Soto, 9',
#          '28002 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3af964a520403d21e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4b00129e6dbe9a8071630b',
#        'name': 'Mallorca',
#        'location': {'address': 'C. Serrano, 6',
#         'lat': 40.421204795826974,
#         'lng': -3.688435136949225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421204795826974,
#           'lng': -3.688435136949225}],
#         'distance': 1249,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Serrano, 6',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4b00129e6dbe9a8071630b-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4c17e71ae437043790f060',
#        'name': 'ORIO Fuencarral',
#        'location': {'address': 'C. Fuencarral, 49',
#         'crossStreet': 'C. Colón',
#         'lat': 40.423747918148486,
#         'lng': -3.70071716655042,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423747918148486,
#           'lng': -3.70071716655042}],
#         'distance': 1013,
#         'postalCode': '28043',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Fuencarral, 49 (C. Colón)',
#          '28043 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33170032'}},
#       'referralId': 'e-0-4d4c17e71ae437043790f060-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb531de93ad2365700b1680',
#        'name': 'Restaurante El Urogallo',
#        'location': {'address': 'Paseo de la Puerta del Ángel, 14',
#         'lat': 40.418807569928816,
#         'lng': -3.7347026548739986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.418807569928816,
#           'lng': -3.7347026548739986}],
#         'distance': 2943,
#         'postalCode': '28011',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Paseo de la Puerta del Ángel, 14',
#          '28011 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb531de93ad2365700b1680-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdadcd063c5c9b6a1392568',
#        'name': 'Puerto Lagasca',
#        'location': {'address': 'C. Lagasca, 81',
#         'lat': 40.431219885426884,
#         'lng': -3.6851105188799234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.431219885426884,
#           'lng': -3.6851105188799234}],
#         'distance': 2254,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Lagasca, 81',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdadcd063c5c9b6a1392568-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '562b925b498e9ffdc792680c',
#        'name': 'Okafú',
#        'location': {'address': 'C/ de Jorge Juan, 29',
#         'lat': 40.42373014673907,
#         'lng': -3.6836658076540942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42373014673907,
#           'lng': -3.6836658076540942}],
#         'distance': 1741,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ de Jorge Juan, 29',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
# ...
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd5ee906f6495218dfa6fec-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc611a751b376b0d0ed1a6f',
#        'name': 'Restaurante Triana',
#        'location': {'address': 'C. Narvaez, 48',
#         'lat': 40.41966385861264,
#         'lng': -3.676106334700902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41966385861264,
#           'lng': -3.676106334700902}],
#         'distance': 2133,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Narvaez, 48',
#          '28009 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '593906726'}},
#       'referralId': 'e-0-4bc611a751b376b0d0ed1a6f-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbd958f6a23e294ba48cec7',
#        'name': 'Ten Con Ten',
#        'location': {'address': 'C. Ayala, 6',
#         'crossStreet': 'P. de la Castellana',
#         'lat': 40.427880944967086,
#         'lng': -3.6884764005263433,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.427880944967086,
#           'lng': -3.6884764005263433}],
#         'distance': 1786,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Ayala, 6 (P. de la Castellana)',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dbd958f6a23e294ba48cec7-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b83c5dff964a520e10f31e3',
#        'name': 'La Pequeña Graná',
#        'location': {'address': 'C. General Palanca, 16',
#         'lat': 40.39957392916725,
#         'lng': -3.6985499739321477,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.39957392916725,
#           'lng': -3.6985499739321477}],
#         'distance': 1685,
#         'postalCode': '28045',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. General Palanca, 16',
#          '28045 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b83c5dff964a520e10f31e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9269b3f964a520c2f733e3',
#        'name': 'La Cumbre',
#        'location': {'address': 'Vía de las Dos Castillas 23',
#         'lat': 40.437495375777424,
#         'lng': -3.7930658799314436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.437495375777424,
#           'lng': -3.7930658799314436}],
#         'distance': 8254,
#         'postalCode': '28224',
#         'cc': 'ES',
#         'city': 'Pozuelo de Alarcón',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Vía de las Dos Castillas 23',
#          '28224 Pozuelo de Alarcón Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9269b3f964a520c2f733e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bab2fd1f964a52079983ae3',
#        'name': 'La Musa Latina',
#        'location': {'address': 'Costanilla de San Andrés, 12',
#         'lat': 40.41283455101768,
#         'lng': -3.7117671604527014,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41283455101768,
#           'lng': -3.7117671604527014}],
#         'distance': 984,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Costanilla de San Andrés, 12',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bab2fd1f964a52079983ae3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c231eb99a67a5937c89dd87',
#        'name': 'El Capataz',
#        'location': {'address': 'Calle de Orense, 10-12 (Bajos AZCA)',
#         'lat': 40.44922481855915,
#         'lng': -3.6942122154581316,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44922481855915,
#           'lng': -3.6942122154581316}],
#         'distance': 3884,
#         'postalCode': '28020',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Orense, 10-12 (Bajos AZCA)',
#          '28020 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c231eb99a67a5937c89dd87-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfe8df32b83b7132ff0a998',
#        'name': 'La Tahona',
#        'location': {'address': 'C. Capitán Haya, 21',
#         'crossStreet': 'Av. Brasil',
#         'lat': 40.45743209541343,
#         'lng': -3.692775662039696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.45743209541343,
#           'lng': -3.692775662039696}],
#         'distance': 4806,
#         'postalCode': '28020',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Capitán Haya, 21 (Av. Brasil)',
#          '28020 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfe8df32b83b7132ff0a998-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '546fa811498e21e3ee443a9d',
#        'name': 'Alma Cheli',
#        'location': {'address': 'Santa Engracia, 103',
#         'lat': 40.437099834696326,
#         'lng': -3.6995737916596436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.437099834696326,
#           'lng': -3.6995737916596436}],
#         'distance': 2500,
#         'postalCode': '28010',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Santa Engracia, 103',
#          '28010 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-546fa811498e21e3ee443a9d-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be06898652b0f47a8577211',
#        'name': 'José Luis',
#        'location': {'address': 'P. San Francisco de Sales, 14',
#         'lat': 40.440667744631554,
#         'lng': -3.7154765342808385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.440667744631554,
#           'lng': -3.7154765342808385}],
#         'distance': 3165,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['P. San Francisco de Sales, 14',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be06898652b0f47a8577211-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b583bc0f964a520e54e28e3',
#        'name': 'Jurucha',
#        'location': {'address': 'C. Ayala, 19',
#         'lat': 40.42775970528889,
#         'lng': -3.6857616768254275,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42775970528889,
#           'lng': -3.6857616768254275}],
#         'distance': 1915,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Ayala, 19', '28001 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b583bc0f964a520e54e28e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b38b459f964a520924f25e3',
#        'name': 'Taberna Cazorla',
#        'location': {'address': 'C. General Pardiñas, 80',
#         'lat': 40.43138511884835,
#         'lng': -3.6780925380180283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43138511884835,
#           'lng': -3.6780925380180283}],
#         'distance': 2654,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. General Pardiñas, 80',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b38b459f964a520924f25e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda36f964a5209b3b21e3',
#        'name': 'Lateral',
#        'location': {'address': 'C. Fuencarral, 43',
#         'lat': 40.42313488092766,
#         'lng': -3.700817360501268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42313488092766,
#           'lng': -3.700817360501268}],
#         'distance': 945,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Fuencarral, 43',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda36f964a5209b3b21e3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5576b396498ebd63fec1e578',
#        'name': 'Restaurante Orgaz',
#        'location': {'address': 'Avda. de los Andes s/n esquina Avda. del Arroyo del Santo',
#         'lat': 40.454565853531776,
#         'lng': -3.6223531108215696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.454565853531776,
#           'lng': -3.6223531108215696}],
#         'distance': 7967,
#         'postalCode': '28042',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Avda. de los Andes s/n esquina Avda. del Arroyo del Santo',
#          '28042 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5576b396498ebd63fec1e578-99'}]}]}}

# %%
spanish_restaurant["response"]["groups"][0]["items"][0]["venue"]["location"]["address"]
# Out:
# 'Calle Juanelo 23'

# %%
spanish_restaurant.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
spanish_restaurant["response"].keys()
# Out:
# dict_keys(['suggestedFilters', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
spanish_restaurant["response"]["suggestedFilters"].keys()
# Out:
# dict_keys(['header', 'filters'])

# %%
spanish_restaurant["response"]["suggestedFilters"]["header"]
# Out:
# 'Tap to show:'

# %%
spanish_restaurant["response"]["suggestedBounds"]
# Out:
# {'ne': {'lat': 40.50465009000009, 'lng': -3.582413019991607},
#  'sw': {'lat': 40.32464990999991, 'lng': -3.8183869800083934}}

# %%
spanish_restaurant["response"]["groups"][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
spanish_restaurant["response"]["groups"][0]["type"]
# Out:
# 'Recommended Places'

# %%
spanish_restaurant["response"]["groups"][0]["name"]
# Out:
# 'recommended'

# %%
spanish_restaurant["response"]["groups"][0]["items"][0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5877d4aed4ab730fcf09092b',
#   'name': 'Toga',
#   'location': {'address': 'Calle Juanelo 23',
#    'lat': 40.41111841899132,
#    'lng': -3.70667299456038,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.41111841899132,
#      'lng': -3.70667299456038}],
#    'distance': 661,
#    'postalCode': '28008',
#    'cc': 'ES',
#    'neighborhood': 'Lavapiés',
#    'city': 'Madrid',
#    'state': 'Madrid',
#    'country': 'España',
#    'formattedAddress': ['Calle Juanelo 23', '28008 Madrid Madrid', 'España']},
#   'categories': [{'id': '4bf58dd8d48988d150941735',
#     'name': 'Spanish Restaurant',
#     'pluralName': 'Spanish Restaurants',
#     'shortName': 'Spanish',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-5877d4aed4ab730fcf09092b-0'}

# %%
spanish_restaurant["response"]["groups"][0]["items"][0].keys()
# Out:
# dict_keys(['reasons', 'venue', 'referralId'])

# %%
spanish_restaurant["response"]["groups"][0]["items"][51]["reasons"]
# Out:
# {'count': 0,
#  'items': [{'summary': 'This spot is popular',
#    'type': 'general',
#    'reasonName': 'globalInteractionReason'}]}

# %%
spanish_restaurant["response"]["groups"][0]["items"][51]["venue"]
# Out:
# {'id': '4bbf22e2b083a5930ee3a2e9',
#  'name': 'De María',
#  'location': {'address': 'C. Félix Boix, 5',
#   'lat': 40.463408449110624,
#   'lng': -3.6882601044052623,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.463408449110624,
#     'lng': -3.6882601044052623}],
#   'distance': 5524,
#   'postalCode': '28036',
#   'cc': 'ES',
#   'city': 'Madrid',
#   'state': 'Madrid',
#   'country': 'España',
#   'formattedAddress': ['C. Félix Boix, 5', '28036 Madrid Madrid', 'España']},
#  'categories': [{'id': '4bf58dd8d48988d150941735',
#    'name': 'Spanish Restaurant',
#    'pluralName': 'Spanish Restaurants',
#    'shortName': 'Spanish',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#     'suffix': '.png'},
#    'primary': True}],
#  'photos': {'count': 0, 'groups': []}}

# %%
spanish_restaurant["response"]["groups"][0]["items"][99]["venue"]["location"]["address"]
# Out:
# 'Avda. de los Andes s/n esquina Avda. del Arroyo del Santo'

# %%
spanish_restaurant["response"]["groups"][0]["items"][0]["venue"]["location"]["address"]
# Out:
# 'Calle Juanelo 23'

# %%
print(spanish_restaurant["response"]["totalResults"])

def obtener_datos(bbdd,n):
    
    names = []
    lat = []
    long = []
    dists = []
    adr = []
   
    for i in range(n):
          
        names.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["name"])
        lat.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["lat"])
        long.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["lng"])
        dists.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["distance"])
        adr.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["address"])
    
    
#    PONER ADDRESS EN EL RETURN
    return names,lat,long,dists,adr
# Out:
# 222

# %%
datos = obtener_datos(spanish_restaurant,100)

datos
# Out:
# (['Toga',
#   'El Barril de las Letras',
#   'Casa Pueblo',
#   'Astór Gastrobar',
#   'El Paraguas',
#   'Cannibal Raw Bar',
#   'Restaurante Viva Madrid',
#   'Bodegas Rosell',
#   'Mercado de Antón Martín',
#   'Bar La Campana',
#   'Pez Tortilla',
#   'La Maruca',
#   'La Manduca de Azagra',
#   'Membibre',
#   'Las Tortillas de Gabino',
#   'Museo del Jamón',
#   'Venta El Buscón',
#   'El Senador',
#   'La Tasquería',
#   'Muñagorri',
#   'Restaurante Lakasa',
#   'Cabreira',
#   'Cañadío',
#   'Castelados',
#   'Lamucca',
#   'El Pimiento Verde',
#   'Cuevas El Secreto',
#   'El Gran Barril',
#   'Makkila Serrano',
#   'TreZe Restaurante & Bar',
#   'la gaditana',
#   'O Pazo de Lugo',
#   'La Casa del Abuelo',
#   'La Antoñita',
#   'Casa Benigna',
#   'Mallorca',
#   'ORIO Fuencarral',
#   'Restaurante El Urogallo',
#   'Puerto Lagasca',
#   'Okafú',
#   'Lateral',
#   'En Busca del Tiempo',
#   'KultO',
#   'Casa Mingo',
#   'Sagardi Castellana',
#   'La Tasquita de Enfrente',
#   'InClan Brutal Bar',
#   'La Máquina de Chamberí',
#   'Mesón Txistu',
#   'La Casita del Pradal',
#   'Rosi La Loca',
#   'De María',
#   'Casa de Valencia',
#   'El Qüenco de Pepa',
#   'Restaurante Rías Bajas',
#   'Viavélez',
#   'La Ancha',
#   'Ondiñas do Mendo',
#   'Paraíso del Jamon',
#   'Casa Juan',
#   'El Hórreo Asturiano',
#   'El Cacique',
#   'Macarena Madrid',
#   'Casa Labra',
#   'El Escondite',
#   'La Raquetista',
#   'Mercado de San Ildefonso',
#   'Casa Lobo',
#   'Alimentación Quiroga',
#   'Carmen Bar',
#   'Casa Dani',
#   'Laredo',
#   'Loreto Coffee-Bar',
#   'Urrechu',
#   'Juan Raro',
#   'Vivares',
#   'Platea Madrid',
#   'La Bobia',
#   'La Tita Rivera',
#   'Sala de Despiece',
#   "O'Buraco",
#   'El Recuerdo',
#   'Matador',
#   'Restaurante Ferreiro',
#   'Jaizkibel',
#   'Trasgu',
#   'Cervecería Jarritus',
#   'Restaurante Triana',
#   'Ten Con Ten',
#   'La Pequeña Graná',
#   'La Cumbre',
#   'La Musa Latina',
#   'El Capataz',
#   'La Tahona',
#   'Alma Cheli',
#   'José Luis',
#   'Jurucha',
#   'Taberna Cazorla',
#   'Lateral',
#   'Restaurante Orgaz'],
#  [40.41111841899132,
#   40.41435989216732,
#   40.41461381230456,
#   40.41273,
#   40.42386542247894,
#   40.42250153573088,
#   40.41516746717612,
#   40.403802520431654,
#   40.41152590000001,
#   40.414881954231625,
#   40.4242382067626,
#   40.42747655521919,
#   40.428413255,
#   40.434911771333695,
#   40.43397126970508,
#   40.416343036500216,
#   40.41611688876583,
#   40.42076966674159,
#   40.42238601054716,
#   40.43129825360115,
#   40.440735363841156,
#   40.42735906133265,
#   40.433172445427076,
#   40.42070698286369,
#   40.423160346582144,
#   40.428865543369945,
#   40.41571802886517,
#   40.424551794594144,
#   40.435157917226896,
#   40.42718847645551,
#   40.42486448041017,
#   40.407589,
#   40.4158078467863,
#   40.4130849147541,
#   40.44809073514549,
#   40.421204795826974,
#   40.423747918148486,
#   40.418807569928816,
#   40.431219885426884,
#   40.42373014673907,
#   40.41457050395633,
#   40.415625674100674,
#   40.41838587249439,
#   40.42482903955803,
#   40.42791007849647,
#   40.421278637837744,
#   40.41502338061646,
#   40.44009910412479,
#   40.46253358253271,
#   40.45850905045048,
#   40.415821011717526,
#   40.463408449110624,
#   40.429916808561934,
#   40.460250549345105,
#   40.44259758352577,
#   40.452314878141024,
#   40.4490694858795,
#   40.45688307624961,
#   40.41776141716171,
#   40.464015,
#   40.46238984809028,
#   40.46258697891609,
#   40.3906324,
#   40.41715,
#   40.42236354072943,
#   40.42046271831923,
#   40.42423010607013,
#   40.45161998001642,
#   40.413759722199444,
#   40.427984394682504,
#   40.427095859479174,
#   40.42031260723626,
#   40.421893687786024,
#   40.41943525634492,
#   40.407007881585116,
#   40.422396252036314,
#   40.426083288964996,
#   40.41138987927906,
#   40.42236378502141,
#   40.43791464602439,
#   40.439775,
#   40.44722910729116,
#   40.4146306440801,
#   40.42170061418621,
#   40.43888537380006,
#   40.39744996061972,
#   40.43027092237046,
#   40.41966385861264,
#   40.427880944967086,
#   40.39957392916725,
#   40.437495375777424,
#   40.41283455101768,
#   40.44922481855915,
#   40.45743209541343,
#   40.437099834696326,
#   40.440667744631554,
#   40.42775970528889,
#   40.43138511884835,
#   40.42313488092766,
#   40.454565853531776],
#  [-3.70667299456038,
#   -3.6967134353360627,
#   -3.6985981117031463,
#   -3.709617,
#   -3.685813532393988,
#   -3.694248172533777,
#   -3.6998336282593405,
#   -3.6906202941279647,
#   -3.6987288,
#   -3.706774570000363,
#   -3.706568309829162,
#   -3.6839650810190783,
#   -3.69965323,
#   -3.7131862406723166,
#   -3.693840964089531,
#   -3.7056822482813363,
#   -3.7017447829143073,
#   -3.7114585151950705,
#   -3.673697687593717,
#   -3.6773280703427838,
#   -3.700766735265493,
#   -3.7039847530463748,
#   -3.675035662601485,
#   -3.6790904867593115,
#   -3.7040597217866043,
#   -3.7154014044180075,
#   -3.7026156381668383,
#   -3.6731258506053215,
#   -3.686353353436428,
#   -3.678429449556118,
#   -3.670859723201479,
#   -3.696473,
#   -3.701593251107847,
#   -3.7085505691060217,
#   -3.6742265886202774,
#   -3.688435136949225,
#   -3.70071716655042,
#   -3.7347026548739986,
#   -3.6851105188799234,
#   -3.6836658076540942,
#   -3.701133477680609,
#   -3.702600895741347,
#   -3.6782228944652724,
#   -3.725446671900649,
#   -3.6899738493773575,
#   -3.7035917760774484,
#   -3.7018643661445174,
#   -3.6991923103876307,
#   -3.693554816416552,
#   -3.655370363275412,
#   -3.7029546044326276,
#   -3.6882601044052623,
#   -3.722415498649063,
#   -3.6845505164314756,
#   -3.6713163349261633,
#   -3.6981016013788146,
#   -3.6776593243227795,
#   -3.7051649232278328,
#   -3.708355925075935,
#   -3.69317,
#   -3.6876584378337895,
#   -3.685273363777068,
#   -3.6912615999999616,
#   -3.7045143,
#   -3.685975461088586,
#   -3.6771653141330463,
#   -3.700819251110139,
#   -3.6497486811054713,
#   -3.6994574585588165,
#   -3.686164944816749,
#   -3.6857193669863895,
#   -3.6751586693950693,
#   -3.7044925983224224,
#   -3.7969799722620774,
#   -3.7010805819249994,
#   -3.6994208517652574,
#   -3.68866416486341,
#   -3.7076682972878503,
#   -3.7003691876569693,
#   -3.6994044892866325,
#   -3.676111,
#   -3.6985534333258663,
#   -3.7029469756383695,
#   -3.721648614221445,
#   -3.6226297293835628,
#   -3.620755577527213,
#   -3.6643420677700576,
#   -3.676106334700902,
#   -3.6884764005263433,
#   -3.6985499739321477,
#   -3.7930658799314436,
#   -3.7117671604527014,
#   -3.6942122154581316,
#   -3.692775662039696,
#   -3.6995737916596436,
#   -3.7154765342808385,
#   -3.6857616768254275,
#   -3.6780925380180283,
#   -3.700817360501268,
#   -3.6223531108215696],
#  [661,
#   314,
#   152,
#   809,
#   1606,
#   1017,
#   74,
#   1464,
#   375,
#   540,
#   1188,
#   1994,
#   1533,
#   2502,
#   2221,
#   485,
#   199,
#   1158,
#   2421,
#   2693,
#   2903,
#   1447,
#   2978,
#   1927,
#   996,
#   2029,
#   222,
#   2560,
#   2574,
#   2327,
#   2749,
#   853,
#   163,
#   712,
#   4333,
#   1249,
#   1013,
#   2943,
#   2254,
#   1741,
#   62,
#   215,
#   1925,
#   2406,
#   1720,
#   785,
#   130,
#   2834,
#   5361,
#   6196,
#   252,
#   5524,
#   2523,
#   5250,
#   3968,
#   4197,
#   4288,
#   4718,
#   758,
#   5529,
#   5422,
#   5488,
#   2783,
#   446,
#   1493,
#   2072,
#   1067,
#   5946,
#   127,
#   1912,
#   1862,
#   2230,
#   877,
#   8202,
#   852,
#   866,
#   1615,
#   714,
#   858,
#   2591,
#   3472,
#   3630,
#   215,
#   1964,
#   7121,
#   7017,
#   3515,
#   2133,
#   1786,
#   1685,
#   8254,
#   984,
#   3884,
#   4806,
#   2500,
#   3165,
#   1915,
#   2654,
#   945,
#   7967],
#  ['Calle Juanelo 23',
#   'C. Cervantes, 28',
#   'Leon 3',
#   '9 Calle del Almendro',
#   'C. Jorge Juan, 16',
#   'Calle Almirante 12',
#   'C. Manuel Fernández y González, 7',
#   'C. General Lacy, 14',
#   'Calle de Santa Isabel 5',
#   'C. Botoneras, 4',
#   'C. Pez, 36',
#   'C. Velázquez, 54',
#   'Calle SAGASTA, 14, BAJO',
#   'Guzman el bueno, 40',
#   'C. Rafael Calvo, 20',
#   'C. Mayor, 7',
#   'C. Victoria, 5',
#   'Plaza de La Marina Española, 2',
#   'Duque de Sesto 48',
#   'C. Padilla, 56',
#   'Pl. Descubridor Diego de Ordás, 1',
#   'C. Ruiz, 2',
#   'C. Conde de Peñalver, 86',
#   'C. Antonio Acuña, 18',
#   'Pl. de Carlos Cambronero 4',
#   'C. Quintana, 1',
#   'C. Barcelona, 2',
#   'C. Goya, 107',
#   'C. Serrano, 110',
#   'C/ general pardiñas 36',
#   'Calle Fuente Del Berri 23',
#   'C. Argumosa 28',
#   'C. Victoria, 12',
#   'C. Cava Baja, 14',
#   'C. Benigno Soto, 9',
#   'C. Serrano, 6',
#   'C. Fuencarral, 49',
#   'Paseo de la Puerta del Ángel, 14',
#   'C. Lagasca, 81',
#   'C/ de Jorge Juan, 29',
#   'Pl. de Santa Ana, 12',
#   'C. Barcelona, 4',
#   'C. Ibiza, 4',
#   'P. de la Florida, 34',
#   'P. de la Castellana, 13',
#   'C. Ballesta, 6',
#   'Calle de Álvarez Gato, 4',
#   'C. Ponzano, 39',
#   'Pl. Ángel Carbajo,  6',
#   'C. Belisana, 17',
#   'Calle Cadiz 4',
#   'C. Félix Boix, 5',
#   'P. Pintor Rosales, 58',
#   'C. Henri Dunant, 23',
#   'C. Alustante, 13',
#   'Av. General Perón 10',
#   'C. Príncipe de Vergara, 204',
#   'C. Villaamil, 4',
#   'C/ Arenal',
#   'C. Infanta Mercedes, 111',
#   'C. Doctor Fleming, 50',
#   'C. Padre Damián, 47',
#   'C/Rodio 6',
#   'C. Tetuán, 12',
#   'Villanueva, 26',
#   'C. Doctor Castelo, 19',
#   'C. Fuencarral, 57',
#   'Torrecilla del Puerto 5',
#   'C. Huertas, 19',
#   'Claudio Coello 61',
#   'C. Ayala, 28',
#   'C. Doctor Castelo, 30',
#   'Corredera baja de San Pablo, 6',
#   'Zoco de Pozuelo',
#   'C. Miguel Servet',
#   'C. Hortaleza, 52',
#   'C. Goya, 5-7',
#   'C. San Millán, 2',
#   'C. Perez Galdós, 4',
#   'C. Ponzano, 11',
#   'Nuestra Señora Del Pilar 10',
#   'C. Comandante Zorita 6',
#   'C/ de la Cruz 39',
#   'P. de la Florida, 15',
#   'C. Albasanz, 67',
#   'Bulevar Jose Prat 27',
#   'C.  Alcalá, 233-235',
#   'C. Narvaez, 48',
#   'C. Ayala, 6',
#   'C. General Palanca, 16',
#   'Vía de las Dos Castillas 23',
#   'Costanilla de San Andrés, 12',
#   'Calle de Orense, 10-12 (Bajos AZCA)',
#   'C. Capitán Haya, 21',
#   'Santa Engracia, 103',
#   'P. San Francisco de Sales, 14',
#   'C. Ayala, 19',
#   'C. General Pardiñas, 80',
#   'C. Fuencarral, 43',
#   'Avda. de los Andes s/n esquina Avda. del Arroyo del Santo'])

# %%
def dataFrame_creation(nombre_dataframe, identificador):
    nombre_final = datos

    nombre_final = list(nombre_final)

    d = {"Identificador": identificador,"Nombre": nombre_final[0], "Latitud": nombre_final[1], "Longitud": nombre_final[2], "Dirección": nombre_final[4]}
    final = pd.DataFrame(data=d)

#     final["Distancia_km"] = final["Distancia_km"]/1000

    final.to_csv(f"{nombre_dataframe}.csv")

# %%
dataFrame_creation("Spanish_Restaurant", "Restaurante Español")

cv = pd.read_csv("Spanish_Restaurant.csv")

cv.head()
# Out:
#    Unnamed: 0        Identificador                   Nombre    Latitud  \
# 0           0  Restaurante Español                     Toga  40.411118
# 1           1  Restaurante Español  El Barril de las Letras  40.414360
# 2           2  Restaurante Español              Casa Pueblo  40.414614
# 3           3  Restaurante Español          Astór Gastrobar  40.412730
# 4           4  Restaurante Español              El Paraguas  40.423865
#
#    Longitud             Dirección
# 0 -3.706673      Calle Juanelo 23
# 1 -3.696713      C. Cervantes, 28
# 2 -3.698598                Leon 3
# 3 -3.709617  9 Calle del Almendro
# 4 -3.685814     C. Jorge Juan, 16

# %% [markdown]
# ## 2. Italian restaurant

# %%
italian_restaurant = data_api("40.4146500,-3.7004000","Italian Restaurant",500,"italian_restaurant")

# %%
print(italian_restaurant["response"]["totalResults"])

datos = obtener_datos(italian_restaurant,100)

datos
# Out:
# 110
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-f75b35d4209a> in <module>
#       1 print(italian_restaurant["response"]["totalResults"])
#       2
# ----> 3 datos = obtener_datos(italian_restaurant,100)
#       4
#       5 datos
#
# <ipython-input-237-c9cf8196847b> in obtener_datos(bbdd, n)
#      15         long.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["lng"])
#      16         dists.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["distance"])
# ---> 17         adr.append(bbdd["response"]["groups"][0]["items"][i]["venue"]["location"]["address"])
#      18
#      19
#
# KeyError: 'address'

# %%
italian_restaurant["response"]["groups"][0]["items"][0]["venue"]["location"]["address"]
# Out:
# 'Calle Gran Via, 6'

# %%
italian_restaurant
# Out:
# {'meta': {'code': 200, 'requestId': '5fd73ed1e1ccea0750da14dd'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Madrid',
#   'headerFullLocation': 'Madrid',
#   'headerLocationGranularity': 'city',
#   'query': 'italian restaurant',
#   'totalResults': 110,
#   'suggestedBounds': {'ne': {'lat': 40.50465009000009,
#     'lng': -3.582413019991607},
#    'sw': {'lat': 40.32464990999991, 'lng': -3.8183869800083934}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5650e689498e59806e43a30f',
#        'name': 'Ôven Mozzarella Bar',
#        'location': {'address': 'Calle Gran Via, 6',
#         'lat': 40.41924524133954,
#         'lng': -3.6978500877927485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41924524133954,
#           'lng': -3.6978500877927485}],
#         'distance': 555,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Gran Via, 6',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5650e689498e59806e43a30f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b65fedbf964a520410d2be3',
#        'name': 'Pizzaiolo',
#        'location': {'address': 'C. Hortaleza, 84',
#         'lat': 40.42379534723905,
#         'lng': -3.698597330722856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42379534723905,
#           'lng': -3.698597330722856}],
#         'distance': 1029,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Hortaleza, 84',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b65fedbf964a520410d2be3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b781a82f964a520f0b52ee3',
#        'name': 'La Tavernetta',
#        'location': {'address': 'C. Orellana, 17',
#         'lat': 40.42607635914717,
#         'lng': -3.6941559395385597,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42607635914717,
#           'lng': -3.6941559395385597}],
#         'distance': 1377,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Orellana, 17',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b781a82f964a520f0b52ee3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d207214756e8cfa645a6c54',
#        'name': 'Pizzeria Italiana Piccolo Diavolo',
#        'location': {'address': 'C. Fúcar, 11',
#         'lat': 40.4115292313695,
#         'lng': -3.695595850047005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4115292313695,
#           'lng': -3.695595850047005}],
#         'distance': 535,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Fúcar, 11', '28014 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d207214756e8cfa645a6c54-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ba92ea7112c6c002cc2703a',
#        'name': 'Nina Pasta Bar',
#        'location': {'address': 'Calle Santa Ana 21',
#         'lat': 40.409508,
#         'lng': -3.7088363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.409508,
#           'lng': -3.7088363}],
#         'distance': 915,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'neighborhood': 'El Rastro',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Santa Ana 21',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ba92ea7112c6c002cc2703a-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b814342f964a520a49c30e3',
#        'name': 'Trattoria Malatesta',
#        'location': {'address': 'C. Coloreros, 5',
#         'crossStreet': 'C. Mayor',
#         'lat': 40.416788,
#         'lng': -3.707182,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416788,
#           'lng': -3.707182}],
#         'distance': 622,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'neighborhood': 'Sol',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Coloreros, 5 (C. Mayor)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33104611'}},
#       'referralId': 'e-0-4b814342f964a520a49c30e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5385ce83498eb1110eee86ea',
#        'name': 'la saletta',
#        'location': {'lat': 40.41163590801957,
#         'lng': -3.6986855712936584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41163590801957,
#           'lng': -3.6986855712936584}],
#         'distance': 365,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5385ce83498eb1110eee86ea-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59aeaadfaa6c95709b89d9a3',
#        'name': 'Fellina',
#        'location': {'address': 'Caracas 21',
#         'lat': 40.430752,
#         'lng': -3.694272,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.430752,
#           'lng': -3.694272}],
#         'distance': 1866,
#         'postalCode': '28010',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Caracas 21', '28010 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59aeaadfaa6c95709b89d9a3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5937f0a29ec3994697c63dd6',
#        'name': 'Numa',
#        'location': {'address': '18 Calle de Velázquez',
#         'lat': 40.42332677352945,
#         'lng': -3.6836398220709308,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42332677352945,
#           'lng': -3.6836398220709308}],
#         'distance': 1717,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['18 Calle de Velázquez',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5937f0a29ec3994697c63dd6-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511a474ce4b03bddc2ac7c58',
#        'name': 'Trattoria In Crescendo',
#        'location': {'address': 'C. Jaime el Conquistador, 31',
#         'lat': 40.39458232012004,
#         'lng': -3.6983880942169574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.39458232012004,
#           'lng': -3.6983880942169574}],
#         'distance': 2240,
#         'postalCode': '28045',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Jaime el Conquistador, 31',
#          '28045 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-511a474ce4b03bddc2ac7c58-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8f7b2cf964a520bb5533e3',
#        'name': 'Trattoria Arcangelo',
#        'location': {'address': 'C.  Moreto, 15',
#         'lat': 40.41336961522739,
#         'lng': -3.6902642454019836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41336961522739,
#           'lng': -3.6902642454019836}],
#         'distance': 870,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C.  Moreto, 15',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8f7b2cf964a520bb5533e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '551c4fbd498eb45d01705086',
#        'name': 'Flavia Restaurante & Bar',
#        'location': {'address': 'C. Gil de Santivañes, 2',
#         'lat': 40.42247356448254,
#         'lng': -3.689587219885726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42247356448254,
#           'lng': -3.689587219885726}],
#         'distance': 1264,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gil de Santivañes, 2',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-551c4fbd498eb45d01705086-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cfad723b399f7002cab78f3',
#        'name': 'Trattoria Popolare',
#        'location': {'address': 'larra 13',
#         'lat': 40.427536,
#         'lng': -3.700076,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.427536,
#           'lng': -3.700076}],
#         'distance': 1434,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['larra 13', '28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5cfad723b399f7002cab78f3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d2cd48e4fa0730023a03559',
#        'name': 'La Mucca',
#        'location': {'lat': 40.427174,
#         'lng': -3.701826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.427174,
#           'lng': -3.701826}],
#         'distance': 1399,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d2cd48e4fa0730023a03559-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc201b0f8219c741615b410',
#        'name': 'Don Giovanni',
#        'location': {'address': 'Paseo de la Reina Cristina 23',
#         'crossStreet': 'posterior',
#         'lat': 40.407648,
#         'lng': -3.680188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.407648,
#           'lng': -3.680188}],
#         'distance': 1882,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Paseo de la Reina Cristina 23 (posterior)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39879781'}},
#       'referralId': 'e-0-4bc201b0f8219c741615b410-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5427ca94498e0b0d25407409',
#        'name': 'Orsomatto',
#        'location': {'address': 'C. Gaztambide, 35',
#         'lat': 40.434012899977404,
#         'lng': -3.7156319618225093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.434012899977404,
#           'lng': -3.7156319618225093}],
#         'distance': 2512,
#         'postalCode': '28015',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gaztambide, 35',
#          '28015 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5427ca94498e0b0d25407409-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5895c8cb375c4a79fee1e877',
#        'name': 'Grosso Napoletano',
#        'location': {'address': 'Calle Hermosilla 85',
#         'lat': 40.42602629298819,
#         'lng': -3.6770535074744846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42602629298819,
#           'lng': -3.6770535074744846}],
#         'distance': 2349,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Hermosilla 85',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5895c8cb375c4a79fee1e877-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549f0e63498ef4e379f2ada9',
#        'name': 'La Tagliatella',
#        'location': {'address': 'C. Preciados 36',
#         'lat': 40.41973334799455,
#         'lng': -3.706735265471105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41973334799455,
#           'lng': -3.706735265471105}],
#         'distance': 780,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Preciados 36',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-549f0e63498ef4e379f2ada9-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af876d8f964a520800d22e3',
#        'name': 'Pizzería Vesuvio',
#        'location': {'address': 'C. Hortaleza, 4',
#         'lat': 40.4205749566079,
#         'lng': -3.700829195519843,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4205749566079,
#           'lng': -3.700829195519843}],
#         'distance': 660,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Hortaleza, 4',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af876d8f964a520800d22e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53470140498e451f8db8fe62',
#        'name': 'Bosco de Lobos',
#        'location': {'address': 'C. Hortaleza, 63',
#         'crossStreet': 'C. Farmacia',
#         'lat': 40.424150785649374,
#         'lng': -3.6990139940797278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.424150785649374,
#           'lng': -3.6990139940797278}],
#         'distance': 1064,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Hortaleza, 63 (C. Farmacia)',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53470140498e451f8db8fe62-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '532d7469498e6f7a11b53ddc',
#        'name': 'Matteo Cucina Italiana',
#        'location': {'address': 'Calle Ayala 28',
#         'lat': 40.427054401800795,
#         'lng': -3.685701435792598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.427054401800795,
#           'lng': -3.685701435792598}],
#         'distance': 1859,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Ayala 28',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '101360180'}},
#       'referralId': 'e-0-532d7469498e6f7a11b53ddc-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3ed967e5e8ae2711cea36b',
#        'name': 'Aió',
#        'location': {'address': 'C. Corredera Baja de San Pablo, 25',
#         'lat': 40.42245957839195,
#         'lng': -3.703875015403938,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42245957839195,
#           'lng': -3.703875015403938}],
#         'distance': 917,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Corredera Baja de San Pablo, 25',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3ed967e5e8ae2711cea36b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519f555f498e520120d5ce28',
#        'name': 'Trattoria Manzoni',
#        'location': {'address': 'Bretón De Los Herreros, 13',
#         'crossStreet': 'Ponzano',
#         'lat': 40.439707551603554,
#         'lng': -3.6994823994838995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.439707551603554,
#           'lng': -3.6994823994838995}],
#         'distance': 2790,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Bretón De Los Herreros, 13 (Ponzano)',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-519f555f498e520120d5ce28-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59f1e8234420d840d9448dfc',
#        'name': 'Grosso Napoletano',
#        'location': {'address': 'Santa Engracia 48',
#         'lat': 40.433806482172656,
#         'lng': -3.698192419929712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.433806482172656,
#           'lng': -3.698192419929712}],
#         'distance': 2140,
#         'postalCode': '28010',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Santa Engracia 48',
#          '28010 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59f1e8234420d840d9448dfc-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a6cfda40fe7a0163b598ef0',
#        'name': 'Numa Pompilio',
#        'location': {'address': 'Calle de Velázquez 18',
#         'lat': 40.423323,
#         'lng': -3.684077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423323,
#           'lng': -3.684077}],
#         'distance': 1686,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Velázquez 18',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a6cfda40fe7a0163b598ef0-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527eb96111d2e85b4b4af9cd',
#        'name': 'Restaurante A vÁnvera',
#        'location': {'address': 'Calle Zurbano,85',
#         'lat': 40.439819598028876,
#         'lng': -3.692768587460466,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.439819598028876,
#           'lng': -3.692768587460466}],
#         'distance': 2875,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Zurbano,85', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94978406'}},
#       'referralId': 'e-0-527eb96111d2e85b4b4af9cd-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5532b7a9498e944a9f268b2e',
#        'name': 'Gioia Restaurante',
#        'location': {'address': 'San Bartolomé 23',
#         'lat': 40.422075,
#         'lng': -3.69859,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.422075,
#           'lng': -3.69859}],
#         'distance': 840,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['San Bartolomé 23', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5532b7a9498e944a9f268b2e-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b858577f964a520306331e3',
#        'name': 'Anema e Core',
#        'location': {'address': 'C/ Donados, 2',
#         'lat': 40.41798081014006,
#         'lng': -3.7083301999038505,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41798081014006,
#           'lng': -3.7083301999038505}],
#         'distance': 767,
#         'postalCode': '28015',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ Donados, 2',
#          '28015 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b858577f964a520306331e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a3d13d392e7a9078973951f',
#        'name': 'Ôven Mozzarella Bar',
#        'location': {'lat': 40.409570819758954,
#         'lng': -3.693256875486928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.409570819758954,
#           'lng': -3.693256875486928}],
#         'distance': 828,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a3d13d392e7a9078973951f-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54e3b586498e31d8fde56c72',
#        'name': 'Reginella',
#        'location': {'address': 'Modesto La Fuente, 72',
#         'lat': 40.4449790213537,
#         'lng': -3.6957598243400587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4449790213537,
#           'lng': -3.6957598243400587}],
#         'distance': 3399,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Modesto La Fuente, 72',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54e3b586498e31d8fde56c72-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc829e05b7aa14348a2337d',
#        'name': 'Mercato Ballaró',
#        'location': {'address': 'C. Santa Engracia, 24',
#         'lat': 40.43101226275812,
#         'lng': -3.6969885796680155,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43101226275812,
#           'lng': -3.6969885796680155}],
#         'distance': 1844,
#         'postalCode': '28010',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Santa Engracia, 24',
#          '28010 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc829e05b7aa14348a2337d-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b32a3bb9d7468002c8616bd',
#        'name': 'Propaganda',
#        'location': {'address': '12 Calle Libertad',
#         'lat': 40.420922,
#         'lng': -3.69733,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.420922,
#           'lng': -3.69733}],
#         'distance': 745,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['12 Calle Libertad',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b32a3bb9d7468002c8616bd-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3af964a520193d21e3',
#        'name': 'Trattoria Pulcinella',
#        'location': {'address': 'Regueros, 7',
#         'lat': 40.424623321374746,
#         'lng': -3.6964957038692723,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.424623321374746,
#           'lng': -3.6964957038692723}],
#         'distance': 1158,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Regueros, 7', '28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3af964a520193d21e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9fce8bf964a520744037e3',
#        'name': 'Accademia Del Gusto',
#        'location': {'address': 'C/ Cristóbal Bordiú 55',
#         'lat': 40.44291207911045,
#         'lng': -3.6962358102437545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44291207911045,
#           'lng': -3.6962358102437545}],
#         'distance': 3165,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ Cristóbal Bordiú 55',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9fce8bf964a520744037e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b485c1af964a5202a4c26e3',
#        'name': 'Regno di Napoli Madrid',
#        'location': {'address': 'C. San Andrés, 21',
#         'lat': 40.42787497934474,
#         'lng': -3.703507731822995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42787497934474,
#           'lng': -3.703507731822995}],
#         'distance': 1495,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. San Andrés, 21',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b485c1af964a5202a4c26e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '531f8e56498e6a649718295b',
#        'name': 'La Mafia se sienta a la mesa',
#        'location': {'address': 'C. Goya, 5',
#         'lat': 40.425704898432215,
#         'lng': -3.688945279786655,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.425704898432215,
#           'lng': -3.688945279786655}],
#         'distance': 1567,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Goya, 5', '28001 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-531f8e56498e6a649718295b-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6db32ff964a520af872ce3',
#        'name': 'Il Piccolino Della Farfalla',
#        'location': {'address': 'C. Huertas, 6',
#         'lat': 40.41404179984918,
#         'lng': -3.700965423239417,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41404179984918,
#           'lng': -3.700965423239417}],
#         'distance': 82,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Huertas, 6',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6db32ff964a520af872ce3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f92aa19e4b01970bb467472',
#        'name': 'La Pasa',
#        'location': {'address': 'C/ San Bernardo 73',
#         'lat': 40.42709975350566,
#         'lng': -3.706565739454684,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42709975350566,
#           'lng': -3.706565739454684}],
#         'distance': 1481,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ San Bernardo 73', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f92aa19e4b01970bb467472-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d166181e190721ec9701421',
#        'name': 'La gula',
#        'location': {'address': 'San Vicente Ferrer',
#         'lat': 40.425611080827835,
#         'lng': -3.7022436197720636,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.425611080827835,
#           'lng': -3.7022436197720636}],
#         'distance': 1230,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['San Vicente Ferrer', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d166181e190721ec9701421-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c57d9c5b1369521059f735a',
#        'name': 'Pizza Napoli',
#        'location': {'address': 'C. de Pradillo, 14',
#         'lat': 40.44868427705434,
#         'lng': -3.6746085110692115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44868427705434,
#           'lng': -3.6746085110692115}],
#         'distance': 4373,
#         'postalCode': '28002',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Pradillo, 14',
#          '28002 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c57d9c5b1369521059f735a-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5426eeb0498ec1f712df2563',
#        'name': 'Oliveto',
#        'location': {'address': 'Calle de Santa Isabel, 45',
#         'crossStreet': 'Marques de Toca',
#         'lat': 40.40971280938963,
#         'lng': -3.696233463330332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.40971280938963,
#           'lng': -3.696233463330332}],
#         'distance': 653,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Santa Isabel, 45 (Marques de Toca)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
# ...
#           'lng': -3.7884298583827007}],
#         'distance': 8009,
#         'postalCode': '28224',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Av. de Europa, 17',
#          '28224 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3af964a5204c3d21e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a89f41498e96a10eec312d',
#        'name': 'Gaeta Caffè Pizzería',
#        'location': {'address': 'Calle AZOFRA, 27, LOC-5',
#         'crossStreet': 'Calle Azofra',
#         'lat': 40.500544102,
#         'lng': -3.671527462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.500544102,
#           'lng': -3.671527462}],
#         'distance': 9869,
#         'postalCode': '28050',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle AZOFRA, 27, LOC-5 (Calle Azofra)',
#          '28050 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '62794421'}},
#       'referralId': 'e-0-51a89f41498e96a10eec312d-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b637e6df964a520367e2ae3',
#        'name': 'Lamucca',
#        'location': {'address': 'Pl. de Carlos Cambronero 4',
#         'crossStreet': 'C. Pez',
#         'lat': 40.423160346582144,
#         'lng': -3.7040597217866043,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423160346582144,
#           'lng': -3.7040597217866043}],
#         'distance': 996,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Carlos Cambronero 4 (C. Pez)',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b637e6df964a520367e2ae3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56850021498ea3199a6e83a9',
#        'name': 'Ginos Méndez Álvaro',
#        'location': {'address': 'C. Méndez Álvaro, 72',
#         'lat': 40.3927510444405,
#         'lng': -3.6782559441417138,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.3927510444405,
#           'lng': -3.6782559441417138}],
#         'distance': 3076,
#         'postalCode': '28045',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Méndez Álvaro, 72',
#          '28045 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56850021498ea3199a6e83a9-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d305bd210e9b1f71038baf1',
#        'name': 'La Bella Anna',
#        'location': {'address': 'Avenida del Monasterio de Silos, 25',
#         'lat': 40.5035898,
#         'lng': -3.7052565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.5035898,
#           'lng': -3.7052565}],
#         'distance': 9909,
#         'postalCode': '28049',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Avenida del Monasterio de Silos, 25',
#          '28049 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d305bd210e9b1f71038baf1-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfe6f1ab68d0f476c27ea57',
#        'name': "L'Angelina",
#        'location': {'lat': 40.45676170441099,
#         'lng': -3.7845003922030847,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.45676170441099,
#           'lng': -3.7845003922030847}],
#         'distance': 8529,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfe6f1ab68d0f476c27ea57-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d8f246498eee66faa4f818',
#        'name': 'O Mamma Mia',
#        'location': {'address': 'Calle Retama 6, Planta 5',
#         'lat': 40.39480732772427,
#         'lng': -3.676478806234899,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.39480732772427,
#           'lng': -3.676478806234899}],
#         'distance': 2998,
#         'postalCode': '28045',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Retama 6, Planta 5',
#          '28045 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53d8f246498eee66faa4f818-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc6fbe47d8b14fb4650e986',
#        'name': 'Rock & Ribs',
#        'location': {'address': 'C.C. Alcalá Norte 414',
#         'crossStreet': 'Local 5',
#         'lat': 40.436830510346354,
#         'lng': -3.6380368480176046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.436830510346354,
#           'lng': -3.6380368480176046}],
#         'distance': 5833,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C.C. Alcalá Norte 414 (Local 5)',
#          '28009 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc6fbe47d8b14fb4650e986-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbdc8414e069c7467159fe3',
#        'name': 'Mia Rafaella Ristorante',
#        'location': {'address': 'Silvano 92',
#         'lat': 40.462595917065784,
#         'lng': -3.6374006859707366,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.462595917065784,
#           'lng': -3.6374006859707366}],
#         'distance': 7548,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Silvano 92', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbdc8414e069c7467159fe3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9e94e8f964a52049f136e3',
#        'name': 'Piccolina',
#        'location': {'address': 'Santiago de Compostela, 28',
#         'lat': 40.483752165971765,
#         'lng': -3.70044225472674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.483752165971765,
#           'lng': -3.70044225472674}],
#         'distance': 7692,
#         'postalCode': '28034',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Santiago de Compostela, 28',
#          '28034 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9e94e8f964a52049f136e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca630f976d3a0935f10ff6a',
#        'name': 'Restaurante OVO Ristorante',
#        'location': {'address': 'Camino Zarzuela, 11, BAJO-IZDA',
#         'crossStreet': 'C. Blanca de Castilla',
#         'lat': 40.464790815533654,
#         'lng': -3.7855363837110807,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.464790815533654,
#           'lng': -3.7855363837110807}],
#         'distance': 9120,
#         'postalCode': '28023',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Camino Zarzuela, 11, BAJO-IZDA (C. Blanca de Castilla)',
#          '28023 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '70415959'}},
#       'referralId': 'e-0-4ca630f976d3a0935f10ff6a-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5738e122498e9e5d0b4ec0d3',
#        'name': 'Restaurante Fratelli',
#        'location': {'lat': 40.389381,
#         'lng': -3.760396,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.389381,
#           'lng': -3.760396}],
#         'distance': 5811,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5738e122498e9e5d0b4ec0d3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c39c3dd3849c928f5c0c1b1',
#        'name': 'La Pizza Italia',
#        'location': {'address': 'Fuente Carrantona 59',
#         'lat': 40.40829580884911,
#         'lng': -3.627882967816343,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.40829580884911,
#           'lng': -3.627882967816343}],
#         'distance': 6187,
#         'postalCode': '28030',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Fuente Carrantona 59',
#          '28030 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c39c3dd3849c928f5c0c1b1-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e356c4362e17d29083355b9',
#        'name': 'Trattoria Di Aluche',
#        'location': {'address': 'C. Guareña, 4',
#         'crossStreet': 'Avenida de los poblados',
#         'lat': 40.38888405348391,
#         'lng': -3.7660243209577686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.38888405348391,
#           'lng': -3.7660243209577686}],
#         'distance': 6258,
#         'postalCode': '28044',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Guareña, 4 (Avenida de los poblados)',
#          '28044 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e356c4362e17d29083355b9-99'}]}]}}

# %%
dataFrame_creation("Italian_Restaurant", "Restaurante Italiano")

cv1 = pd.read_csv("Italian_Restaurant.csv")

cv1.head()
# Out:
#    Unnamed: 0         Identificador                   Nombre    Latitud  \
# 0           0  Restaurante Italiano                     Toga  40.411118
# 1           1  Restaurante Italiano  El Barril de las Letras  40.414360
# 2           2  Restaurante Italiano              Casa Pueblo  40.414614
# 3           3  Restaurante Italiano          Astór Gastrobar  40.412730
# 4           4  Restaurante Italiano              El Paraguas  40.423865
#
#    Longitud             Dirección
# 0 -3.706673      Calle Juanelo 23
# 1 -3.696713      C. Cervantes, 28
# 2 -3.698598                Leon 3
# 3 -3.709617  9 Calle del Almendro
# 4 -3.685814     C. Jorge Juan, 16

# %% [markdown]
# ## 3. Museos de Arte

# %%
art_museum = data_api("40.4146500,-3.7004000","Art Museum",300,"art_museum")

# %%
print(art_museum["response"]["totalResults"])

datos = obtener_datos(art_museum,21)
# Out:
# 34

# %%
dataFrame_creation("Art_Museum", "Museo de Arte")
                   
cv2 = pd.read_csv("Art_Museum.csv")
                   
cv2.head()
# Out:
#    Unnamed: 0  Identificador  \
# 0           0  Museo de Arte
# 1           1  Museo de Arte
# 2           2  Museo de Arte
# 3           3  Museo de Arte
# 4           4  Museo de Arte
#
#                                               Nombre    Latitud  Longitud  \
# 0  Museo Nacional Centro de Arte Reina Sofía (MNC...  40.408737 -3.693822
# 1                           Museo Thyssen-Bornemisza  40.416359 -3.694891
# 2                           Museo Nacional del Prado  40.413978 -3.692189
# 3                                  CaixaForum Madrid  40.411013 -3.693177
# 4                       Espacio Fundación Telefónica  40.420392 -3.701617
#
#    Distancia_km
# 0         0.862
# 1         0.504
# 2         0.699
# 3         0.734
# 4         0.647

# %% [markdown]
# ## 4. Soccer Stadium

# %%
soccer_stadium = data_api("40.4146500,-3.7004000","Soccer Stadium",300,"soccer_stadium")

# %%
print(soccer_stadium["response"]["totalResults"])

datos = obtener_datos(soccer_stadium,14)
# Out:
# 14

# %%
dataFrame_creation("Soccer_stadium", "Estadio de Fútbol")

cv3 = pd.read_csv("Soccer_stadium.csv")

cv3.head()
# Out:
#    Unnamed: 0      Identificador                      Nombre    Latitud  \
# 0           0  Estadio de Fútbol   Estadio Santiago Bernabéu  40.453062
# 1           1  Estadio de Fútbol    Estadio Vicente Calderón  40.402071
# 2           2  Estadio de Fútbol              Players Tunnel  40.453130
# 3           3  Estadio de Fútbol  Palco De Honor (Royal Box)  40.453372
# 4           4  Estadio de Fútbol         Estadio de Vallecas  40.391747
#
#    Longitud  Distancia_km
# 0 -3.688338         4.396
# 1 -3.720382         2.197
# 2 -3.687860         4.413
# 3 -3.688411         4.428
# 4 -3.658640         4.362

# %% [markdown]
# ## 5. Outdoor Sculpture

# %%
outdoor_sculpture = data_api("40.4146500,-3.7004000","Outdoor Sculpture",300,"outdoor_sculpture")

# %%
print(outdoor_sculpture["response"]["totalResults"])

datos = obtener_datos(outdoor_sculpture,26)
# Out:
# 26

# %%
dataFrame_creation("Outdoor_Sculpture", "Escultura Exterior")

cv4 = pd.read_csv("Outdoor_Sculpture.csv")

cv4.head()
# Out:
#    Unnamed: 0       Identificador                           Nombre    Latitud  \
# 0           0  Escultura Exterior                Luminoso Tío Pepe  40.416771
# 1           1  Escultura Exterior  Monumento A Miguel De Cervantes  40.415615
# 2           2  Escultura Exterior                Casa De Papá Noel  40.416034
# 3           3  Escultura Exterior                 Ángel estrellado  40.415672
# 4           4  Escultura Exterior       Stormtrooper #FacetheForce  40.408771
#
#    Longitud  Distancia_km
# 0 -3.703344         0.343
# 1 -3.696507         0.346
# 2 -3.704201         0.357
# 3 -3.709996         0.821
# 4 -3.693228         0.893

# %% [markdown]
# ## 6. History Museum

# %%
history_museum = data_api("40.4146500,-3.7004000","History Museum",300,"history_museum")

# %%
print(history_museum["response"]["totalResults"])

datos = obtener_datos(history_museum,20)
# Out:
# 20

# %%
dataFrame_creation("History_Museum", "Museo de Historia")

cv5 = pd.read_csv("History_Museum.csv")

cv5.head()
# Out:
#    Unnamed: 0      Identificador                             Nombre  \
# 0           0  Museo de Historia  Museo Arqueológico Nacional (MAN)
# 1           1  Museo de Historia                 Imprenta Municipal
# 2           2  Museo de Historia              Museo Naval de Madrid
# 3           3  Museo de Historia                    Templo de Debod
# 4           4  Museo de Historia                      Museo Sorolla
#
#      Latitud  Longitud  Distancia_km
# 0  40.423259 -3.688432         1.395
# 1  40.413663 -3.705448         0.441
# 2  40.417721 -3.693211         0.698
# 3  40.424164 -3.716843         1.750
# 4  40.435248 -3.692374         2.391

# %% [markdown]
# ## PUNTOS QUE ME INTERESAN
#
# - Museum
#     - Art Museum
#     - History Museum
#
# - Public Art
#     - Outdoor Sculpture
#     - Street Art
#
# - Stadium
#     - Soccer Stadium

# %% [markdown]
# # Links importantes
#
# ## 1. Four Square
#
# - Regular API Endpoints: https://developer.foursquare.com/docs/places-api/endpoints/
# - Realizar llamada a la API: https://developer.foursquare.com/docs/places-api/getting-started/
# - Categoría de los eventos: https://developer.foursquare.com/docs/build-with-foursquare/categories/
#
# ## 2. Folium
#
# - Documentación 1: https://python-visualization.github.io/folium/
# - Documentación 2: https://python-visualization.github.io/folium/modules.html
# - Iconos 1: https://fontawesome.com/v4.7.0/icons/
# - Iconos 2: https://getbootstrap.com/docs/3.3/components/
