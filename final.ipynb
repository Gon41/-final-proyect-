# %%
from funciones_AIRBNB import busquedas_piso,calcular_km,normalizar
from funciones_MAPA import pintar_mapa
from haversine import haversine, Unit 
from funciones_FINAL import airbnb_final

import pandas as pd

# %% [markdown]
# <img src="../-final-proyect-/mapa_punto.jpg">

# %% [markdown]
# ### Tipos de alojamiento
#
# <img src="../-final-proyect-/Tipos_apartamento.ppg">

# %% [markdown]
# ## ####CAMBIAR#####Función: Obtener el mapa
#
# El objetivo es introducir una serie de parámetros para obtener un mapa completo con las ubicaciones cercanas al airbnb elegido
#
# Introduzco los valores:
#
# 1) **lat_airbnb**: (Latitud del airbnb) En forma de número entero.
# *Ej: 40.4146500*
#
# 2) **lon_airbnb**: (Latitud del airbnb) En forma de número entero.
# *Ej: -3.71340*
#
# 3) **distance**: (Radio de acción) En forma de número entero. Indica los kilómetros alrededor
# *Ej: 10*
#
# 4) **number**: (Número máximo de elementos que queremos ver por cada identificador) En forma de número entero.
# *Ej: 10*

# %%
def airbnb():
    
    distrito = str(input("Introduce el distrito de Madrid dónde quieres alojarte: "))
    kind = str(input("¿Qué tipo de alojamiento deseas? (Entire home/apt, Private room, Shared room o Hotel room): "))
    min_price = int(input("Introduce el mínimo precio que estás dispuesto a pagar: "))
    max_price = int(input("Introduce el máximo precio que estás dispuesto a pagar: "))
    minimum_nights = int(input("Introduce el mínimo de noches que quieres alojarte: "))
    number_reviews = int(input("Introduce el mínimo de reseñas que quieras que tenga el anuncio del alojamiento: "))
    distance = int(input("¿Qué radio máximo (en km) quieres ver: "))
    number = int(input("¿Cuántos identificadores como máximo quieres ver de cada tipo: "))
                         
    pisos = busquedas_piso(distrito, kind, min_price, max_price, minimum_nights,number_reviews)
    
    while pisos == 0:
        
        break
    
    else:

        data = pd.read_csv("Pisos_elegidos.csv")

        id_airbnb = int(input("Introduce el ID del airbnb seleccionado: "))

        lst_coord = data.loc[((data["id"] == id_airbnb))]
        lat,lon = lst_coord["latitude"],lst_coord["longitude"]



        calcular_km(lat,lon)

        normalizar()

        return pintar_mapa(lat,lon,distance,number)

# %%
airbnb()

# %%
airbnb_final()
# Out:
# Introduce el distrito de Madrid dónde quieres alojarte: Chamberí
# ¿Qué tipo de alojamiento deseas? (Entire home/apt, Private room, Shared room o Hotel room): Shared room
# Introduce el mínimo precio que estás dispuesto a pagar: 15
# Introduce el máximo precio que estás dispuesto a pagar: 50
# Introduce el mínimo de noches que quieres alojarte: 2
# Introduce el mínimo de reseñas que quieras que tenga el anuncio del alojamiento: 5
# ¿Qué radio máximo (en km) quieres ver: 10
# ¿Cuántos identificadores como máximo quieres ver de cada tipo: 15
#           id   host_id neighbourhood_group neighbourhood    room_type  price  \
# 949  3362113  16958375            Chamberí     Trafalgar  Shared room     18
#
#      latitude  longitude  minimum_nights  number_of_reviews  availability_365  \
# 949  40.43159   -3.70181               2                 11                 0
#
#     host_name
# 949    Sylvia
# Introduce el ID del airbnb seleccionado: 3362113
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
